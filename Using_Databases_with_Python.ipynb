# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# # ***Lecture 15.4 : Worked Example: Counting Email in a Database***

# %%
import sqlite3

conn = sqlite3.connect('emaildb.sqlite')
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Counts')

cur.execute('''CREATE TABLE Counts (email TEXT, count INTEGER)''')

fname = input('Enter file name: ')
if (len(fname) < 1): fname = 'mbox-short.txt'
fh = open(fname)
for line in fh:
    if not line.startswith('From: '): continue
    pieces = line.split()
    email = pieces[1]
    cur.execute('SELECT count FROM Counts WHERE email = ? ', (email,))
    row = cur.fetchone()
    if row is None:
        cur.execute('''INSERT INTO Counts (email, count) VALUES (?, 1)''', (email,))
    else:
        cur.execute('UPDATE Counts SET count = count + 1 WHERE email = ?', (email,))
    conn.commit()

# https://www.sqlite.org/lang_select.html
sqlstr = 'SELECT email, count FROM Counts ORDER BY count DESC LIMIT 10'

for row in cur.execute(sqlstr):
    print(str(row[0]), row[1])

cur.close()
# Out:
# Enter file name: mbox.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-61472c315339> in <module>
#      21     else:
#      22         cur.execute('UPDATE Counts SET count = count + 1 WHERE email = ?', (email,))
# ---> 23     conn.commit()
#      24
#      25 # https://www.sqlite.org/lang_select.html
#
# KeyboardInterrupt:

# %% [markdown]
# # ***week 2 - Assignment 2: Counting Email in a Database***

# %%
import sqlite3

conn = sqlite3.connect('org_count.sqlite')
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Counts')

cur.execute('''
CREATE TABLE Counts (org TEXT, count INTEGER)''')

fname = input('Enter file name: ')
if (len(fname) < 1): fname = 'mbox.txt'
fh = open(fname)
for line in fh:
    if not line.startswith('From: '):
        continue
    pieces = line.split()
    org = pieces[1]
    data = org.split("@")
    print(data)
    org_e = data[1]
    print(org_e)
    cur.execute('SELECT count FROM Counts WHERE org = ? ', (org_e,))
    row = cur.fetchone()
    if row is None:
        cur.execute('INSERT INTO Counts (org, count) VALUES (?, 1)', (org_e,))
    else:
        cur.execute('UPDATE Counts SET count = count + 1 WHERE org = ?', (org_e,))
    conn.commit()
sqlstr = 'SELECT org, count FROM Counts ORDER BY count DESC LIMIT 10'

for row in cur.execute(sqlstr):
    print(str(row[0]), row[1])
    
cur.close()
# Out:
# Enter file name:
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['tnguyen', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['aaronz', 'vt.edu']
# vt.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['csev', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['csev', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['knoop', 'umich.edu']
# umich.edu
# ['knoop', 'umich.edu']
# umich.edu
# ['knoop', 'umich.edu']
# umich.edu
# ['knoop', 'umich.edu']
# umich.edu
# ['knoop', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['bkirschn', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['dlhaines', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['hu2', 'iupui.edu']
# iupui.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['hu2', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['tnguyen', 'iupui.edu']
# iupui.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['arwhyte', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['dlhaines', 'umich.edu']
# umich.edu
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gbhatnag', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['tnguyen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['tnguyen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['tnguyen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['lance', 'indiana.edu']
# indiana.edu
# ['lance', 'indiana.edu']
# indiana.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['lance', 'indiana.edu']
# indiana.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['lance', 'indiana.edu']
# indiana.edu
# ['lance', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['ssmail', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['jlrenfro', 'ucdavis.edu']
# ucdavis.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['nuno', 'ufp.pt']
# ufp.pt
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['nuno', 'ufp.pt']
# ufp.pt
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['nuno', 'ufp.pt']
# ufp.pt
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['stephen.marquard', 'uct.ac.za']
# uct.ac.za
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['tnguyen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['lance', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['cwen', 'iupui.edu']
# iupui.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['jimeng', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ssmail', 'indiana.edu']
# indiana.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['gbhatnag', 'umich.edu']
# umich.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gbhatnag', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['jimeng', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['jimeng', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['jimeng', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['jleasia', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['dlhaines', 'umich.edu']
# umich.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['dlhaines', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ssmail', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ssmail', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['stuart.freeman', 'et.gatech.edu']
# et.gatech.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['aaronz', 'vt.edu']
# vt.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['lance', 'indiana.edu']
# indiana.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ggolden', 'umich.edu']
# umich.edu
# ['ggolden', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ggolden', 'umich.edu']
# umich.edu
# ['ggolden', 'umich.edu']
# umich.edu
# ['ggolden', 'umich.edu']
# umich.edu
# ['ggolden', 'umich.edu']
# umich.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ssmail', 'indiana.edu']
# indiana.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['aaronz', 'vt.edu']
# vt.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['lance', 'indiana.edu']
# indiana.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['thoppaymallika', 'fhda.edu']
# fhda.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['zqian', 'umich.edu']
# umich.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['jimeng', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['bkirschn', 'umich.edu']
# umich.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['zqian', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['zqian', 'umich.edu']
# umich.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['hu2', 'iupui.edu']
# iupui.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['aaronz', 'vt.edu']
# vt.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ...
# ['arwhyte', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['arwhyte', 'umich.edu']
# umich.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ggolden', 'umich.edu']
# umich.edu
# ['antranig', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ggolden', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['gopal.ramasammycook', 'gmail.com']
# gmail.com
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['hu2', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['csev', 'umich.edu']
# umich.edu
# ['josrodri', 'iupui.edu']
# iupui.edu
# ['csev', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['bahollad', 'indiana.edu']
# indiana.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['csev', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['nuno', 'ufp.pt']
# ufp.pt
# ['nuno', 'ufp.pt']
# ufp.pt
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['zqian', 'umich.edu']
# umich.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['jimeng', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['ostermmg', 'whitman.edu']
# whitman.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['hu2', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['zqian', 'umich.edu']
# umich.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['bahollad', 'indiana.edu']
# indiana.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['sgithens', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['zqian', 'umich.edu']
# umich.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['john.ellis', 'rsmart.com']
# rsmart.com
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['nuno', 'ufp.pt']
# ufp.pt
# ['kimsooil', 'bu.edu']
# bu.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['jleasia', 'umich.edu']
# umich.edu
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['mmmay', 'indiana.edu']
# indiana.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['hu2', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['kimsooil', 'bu.edu']
# bu.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['hu2', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['gsilver', 'umich.edu']
# umich.edu
# ['mbreuker', 'loi.nl']
# loi.nl
# ['mbreuker', 'loi.nl']
# loi.nl
# ['mbreuker', 'loi.nl']
# loi.nl
# ['mbreuker', 'loi.nl']
# loi.nl
# ['mbreuker', 'loi.nl']
# loi.nl
# ['mbreuker', 'loi.nl']
# loi.nl
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['a.fish', 'lancaster.ac.uk']
# lancaster.ac.uk
# ['dlhaines', 'umich.edu']
# umich.edu
# ['mbreuker', 'loi.nl']
# loi.nl
# ['david.horwitz', 'uct.ac.za']
# uct.ac.za
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['jimeng', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['colin.clark', 'utoronto.ca']
# utoronto.ca
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['wagnermr', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['bahollad', 'indiana.edu']
# indiana.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['bahollad', 'indiana.edu']
# indiana.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['mbreuker', 'loi.nl']
# loi.nl
# ['zqian', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['louis', 'media.berkeley.edu']
# media.berkeley.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['bkirschn', 'umich.edu']
# umich.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ray', 'media.berkeley.edu']
# media.berkeley.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['mbreuker', 'loi.nl']
# loi.nl
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['dlhaines', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['gjthomas', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['cwen', 'iupui.edu']
# iupui.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['gsilver', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['ajpoland', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['rjlowe', 'iupui.edu']
# iupui.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['ktsao', 'stanford.edu']
# stanford.edu
# ['ian', 'caret.cam.ac.uk']
# caret.cam.ac.uk
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['zqian', 'umich.edu']
# umich.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['aaronz', 'vt.edu']
# vt.edu
# ['jzaremba', 'unicon.net']
# unicon.net
# ['dlhaines', 'umich.edu']
# umich.edu
# ['chmaurer', 'iupui.edu']
# iupui.edu
# ['zach.thomas', 'txstate.edu']
# txstate.edu
# ['dlhaines', 'umich.edu']
# umich.edu
# iupui.edu 536
# umich.edu 491
# indiana.edu 178
# caret.cam.ac.uk 157
# vt.edu 110
# uct.ac.za 96
# media.berkeley.edu 56
# ufp.pt 28
# gmail.com 25
# et.gatech.edu 17

# %% [markdown]
# # *Bonus Worked Example: Twspider.py (Chapter 15)*

# %%
# Keep this file separate

# https://apps.twitter.com/
# Create new App and get the four strings

def oauth():
    return {"consumer_key": "h7Lu...Ng",
            "consumer_secret": "dNKenAC3New...mmn7Q",
            "token_key": "10185562-eibxCp9n2...P4GEQQOSGI",
            "token_secret": "H0ycCFemmC4wyf1...qoIpBo"}

# %%
from urllib.request import urlopen
import urllib.error
import twurl
import json
import sqlite3
import ssl

TWITTER_URL = 'https://api.twitter.com/1.1/friends/list.json'

conn = sqlite3.connect('spider.sqlite')
cur = conn.cursor()

cur.execute('''
            CREATE TABLE IF NOT EXISTS Twitter
            (name TEXT, retrieved INTEGER, friends INTEGER)''')

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    acct = input('Enter a Twitter account, or quit: ')
    if (acct == 'quit'): break
    if (len(acct) < 1):
        cur.execute('SELECT name FROM Twitter WHERE retrieved = 0 LIMIT 1')
        try:
            acct = cur.fetchone()[0]
        except:
            print('No unretrieved Twitter accounts found')
            continue

    url = twurl.augment(TWITTER_URL, {'screen_name': acct, 'count': '20'})
    print('Retrieving', url)
    connection = urlopen(url, context=ctx)
    data = connection.read().decode()
    headers = dict(connection.getheaders())

    print('Remaining', headers['x-rate-limit-remaining'])
    js = json.loads(data)
    # Debugging
    # print json.dumps(js, indent=4)

    cur.execute('UPDATE Twitter SET retrieved=1 WHERE name = ?', (acct, ))

    countnew = 0
    countold = 0
    for u in js['users']:
        friend = u['screen_name']
        print(friend)
        cur.execute('SELECT friends FROM Twitter WHERE name = ? LIMIT 1',
                    (friend, ))
        try:
            count = cur.fetchone()[0]
            cur.execute('UPDATE Twitter SET friends = ? WHERE name = ?',
                        (count+1, friend))
            countold = countold + 1
        except:
            cur.execute('''INSERT INTO Twitter (name, retrieved, friends)
                        VALUES (?, 0, 1)''', (friend, ))
            countnew = countnew + 1
    print('New accounts=', countnew, ' revisited=', countold)
    conn.commit()

cur.close()
# Out:
# Enter a Twitter account, or quit: sm_sowrav
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-af187ed54505> in <module>
#      31             continue
#      32
# ---> 33     url = twurl.augment(TWITTER_URL, {'screen_name': acct, 'count': '20'})
#      34     print('Retrieving', url)
#      35     connection = urlopen(url, context=ctx)
#
# NameError: name 'twurl' is not defined

# %% [markdown]
# # *Worked Example: Tracks.py (Chapter 15)*

# %%
import xml.etree.ElementTree as ET
import sqlite3

conn = sqlite3.connect('trackdb.sqlite')
cur = conn.cursor()

# Make some fresh tables using executescript()
cur.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    len INTEGER, rating INTEGER, count INTEGER
);
''')


fname = input('Enter file name: ')
if ( len(fname) < 1 ) : fname = 'Library.xml'

# <key>Track ID</key><integer>369</integer>
# <key>Name</key><string>Another One Bites The Dust</string>
# <key>Artist</key><string>Queen</string>
def lookup(d, key):
    found = False
    for child in d:
        if found : return child.text
        if child.tag == 'key' and child.text == key :
            found = True
    return None

stuff = ET.parse(fname)
all = stuff.findall('dict/dict/dict')
print('Dict count:', len(all))
for entry in all:
    if ( lookup(entry, 'Track ID') is None ) : continue

    name = lookup(entry, 'Name')
    artist = lookup(entry, 'Artist')
    album = lookup(entry, 'Album')
    count = lookup(entry, 'Play Count')
    rating = lookup(entry, 'Rating')
    length = lookup(entry, 'Total Time')

    if name is None or artist is None or album is None : 
        continue

    print(name, artist, album, count, rating, length)

    cur.execute('''INSERT OR IGNORE INTO Artist (name) 
        VALUES ( ? )''', ( artist, ) )
    cur.execute('SELECT id FROM Artist WHERE name = ? ', (artist, ))
    artist_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Album (title, artist_id) 
        VALUES ( ?, ? )''', ( album, artist_id ) )
    cur.execute('SELECT id FROM Album WHERE title = ? ', (album, ))
    album_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Track
        (title, album_id, len, rating, count) 
        VALUES ( ?, ?, ?, ?, ? )''', 
        ( name, album_id, length, rating, count ) )

    conn.commit()

# %% [markdown]
# # Assignment: Multi-Table Database - Tracks

# %%
import xml.etree.ElementTree as ET
import sqlite3

conn = sqlite3.connect('trackdb.sqlite')
cur = conn.cursor()

# Make some fresh tables using executescript()
cur.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Genre;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Genre (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    genre_id  INTEGER,
    len INTEGER, rating INTEGER, count INTEGER
);

''')


fname = input('Enter file name: ')
if ( len(fname) < 1 ) : fname = 'Library.xml'

# <key>Track ID</key><integer>369</integer>
# <key>Name</key><string>Another One Bites The Dust</string>
# <key>Artist</key><string>Queen</string>
def lookup(d, key):
    found = False
    for child in d:
        if found : return child.text
        if child.tag == 'key' and child.text == key :
            found = True
    return None

stuff = ET.parse(fname)
all = stuff.findall('dict/dict/dict')
print('Dict count:', len(all))
for entry in all:
    if ( lookup(entry, 'Track ID') is None ) : continue

    name = lookup(entry, 'Name')
    artist = lookup(entry, 'Artist')
    album = lookup(entry, 'Album')
    count = lookup(entry, 'Play Count')
    rating = lookup(entry, 'Rating')
    length = lookup(entry, 'Total Time')
    genre = lookup(entry, 'Genre')
    

    if name is None or artist is None or album is None or genre is None: 
        continue

    print(name, artist, album, count, rating, length, genre)

    cur.execute('''INSERT OR IGNORE INTO Artist (name) 
        VALUES ( ? )''', ( artist, ) )
    cur.execute('SELECT id FROM Artist WHERE name = ? ', (artist, ))
    artist_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Album (title, artist_id) 
        VALUES ( ?, ? )''', ( album, artist_id ) )
    cur.execute('SELECT id FROM Album WHERE title = ? ', (album, ))
    album_id = cur.fetchone()[0]
    
    cur.execute('''INSERT OR IGNORE INTO Genre (name)
    VALUES (?)''', (genre, ) )
    cur.execute('SELECT id FROM Genre WHERE name = ? ', (genre, ))
    genre_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Track
        (title, album_id, genre_id, len, rating, count) 
        VALUES ( ?, ?, ?, ?, ?, ? )''', 
        ( name, album_id, genre_id, length, rating, count ) )

    conn.commit()

sqlstr = 'SELECT Track.title, Artist.name, Album.title, Genre.name FROM Track JOIN Genre JOIN Album JOIN Artist ON Track.genre_id = Genre.ID and Track.album_id = Album.id AND Album.artist_id = Artist.id ORDER BY Artist.name LIMIT 3'

#print(sqlstr)
for row in cur.execute(sqlstr) :
    print (str(row[0]),str(row[1]),str(row[2]),str(row[3]) )

cur.close()
# Out:
# Enter file name:
# Dict count: 404
# Another One Bites The Dust Queen Greatest Hits 55 100 217103 Rock
# Asche Zu Asche Rammstein Herzeleid 79 100 231810 Industrial
# Beauty School Dropout Various Grease 48 100 239960 Soundtrack
# Black Dog Led Zeppelin IV 109 100 296620 Rock
# Bring The Boys Back Home Pink Floyd The Wall [Disc 2] 33 100 87118 Rock
# Circles Bryan Lee Blues Is 54 60 355369 Funk
# Comfortably Numb Pink Floyd The Wall [Disc 2] 36 100 384130 Rock
# Crazy Little Thing Called Love Queen Greatest Hits 38 100 163631 Rock
# Electric Funeral Black Sabbath Paranoid 44 100 293015 Metal
# Fat Bottomed Girls Queen Greatest Hits 38 100 257515 Rock
# For Those About To Rock (We Salute You) AC/DC Who Made Who 84 100 353750 Rock
# Four Sticks Led Zeppelin IV 84 100 284421 Rock
# Furious Angels Rob Dougan The Matrix Reloaded 54 100 330004 Soundtrack
# Gelle Bryan Lee Blues Is 45 60 199836 Blues/R&B
# Going To California Led Zeppelin IV 100 100 215666 Rock
# Grease Various Grease 42 100 205792 Soundtrack
# Hand of Doom Black Sabbath Paranoid 36 100 429609 Metal
# Hells Bells AC/DC Who Made Who 82 100 312946 Rock
# Hey You Pink Floyd The Wall [Disc 2] 23 100 282305 Rock
# I Worry Bryan Lee Blues Is 33 100 341315 Blues/R&B
.mp3 Created by Sakai SI 664 W14's official Podcast. None None 3624312 Podcast
# PHP-06-Objects.mp3 Created by Sakai SI 664 W14's official Podcast. None None 2455368 Podcast
# SI664-13-JSON-A.mp3 Created by Sakai SI 664 W14's official Podcast. None None 4407672 Podcast
# PHP-13-JavaScript.mp3 Created by Sakai SI 664 W14's official Podcast. None None 3650088 Podcast
# PHP-09-Database-Design.mp3 Created by Sakai SI 664 W14's official Podcast. None None 3591072 Podcast
# PHP-Tsugi-Install.mp3 Created by Sakai SI 664 W14's official Podcast. None None 3181656 Podcast
# PHP-10-MySQL-PDO.mp3 Created by Sakai SI 664 W14's official Podcast. None None 4536685 Podcast
# PHP-08-MySQL.mp3 Created by Sakai SI 664 W14's official Podcast. None None 3994656 Podcast
# SI664-13-JSON-B.mp3 Created by Sakai SI 664 W14's official Podcast. None None 1484616 Podcast
# IMS-Learning-Tools-Interoperability.mp3 Created by Sakai SI 664 W14's official Podcast. None None 2185848 Podcast
# An Interview with Don Waters Matt Pasiewicz CNI Event Coverage 2 None 1411082 Speech
# PY4INF-11-Regex.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2123702 Podcast
# PY4INF-10-Tuples.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1597596 Podcast
# PY4INF-09-Dictionaries.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2254445 Podcast
# PY4INF-08-Lists.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1636231 Podcast
# PY4INF-07-Files.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1478713 Podcast
# PY4INF-06-Strings.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1677844 Podcast
# PY4INF-05-Iterations.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2804297 Podcast
# PY4INF-04-Functions.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1683800 Podcast
# PY4INF-03-Conditional.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2296058 Podcast
# PY4INF-02-Expressions.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2578416 Podcast
# PY4INF-01-Intro.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 3428075 Podcast
# Py4Inf-11-Regex.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2123702 Podcast
# Py4Inf-10-Tuples.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1597596 Podcast
# Py4Inf-09-Dictionaries.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2254445 Podcast
# Py4Inf-08-Lists.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1636231 Podcast
# Py4Inf-07-Files.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1478713 Podcast
# Py4Inf-06-Strings.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1677844 Podcast
# Py4Inf-05-Iterations.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2804297 Podcast
# Py4Inf-04-Functions.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 1683800 Podcast
# Py4Inf-03-Conditional.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2296058 Podcast
# Py4Inf-02-Expressions.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 2578416 Podcast
# Py4Inf-01-Intro.mp3 Recording by Dr. Chuck Python for Informatics's official Podcast. None None 3428075 Podcast
# Ian Foster on the Globus Project IEEE Computer Society Computing Conversations 1 None 538305 Podcast
# Khan Academy and Computer Science IEEE Computer Society Computing Conversations 1 None 558837 Podcast
# Guido van Rossumon the Early Years of Python IEEE Computer Society Computing Conversations 1 None 701884 Podcast
# Guido van Rossum on the Modern Era of Python IEEE Computer Society Computing Conversations None None 741616 Podcast
# John Resig on Building jQuery IEEE Computer Society Computing Conversations None None 595983 Podcast
# Roy T. Fielding on Understanding the REST Style IEEE Computer Society Computing Conversations 1 None 683650 Podcast
# Anil Jain: 25 Years of Biometric Recognition IEEE Computer Society Computing Conversations None None 661368 Podcast
# Waste Management Undercover Boss Undercover Boss, Season 1 1 None 2565232 Reality TV
# Sleep Like a Baby Tonight U2 Songs of Innocence None None 301641 Rock
# Evergreen The Black Crowes Warpaint None None 261373 Rock
# Oh Josephine The Black Crowes Warpaint None None 398907 Rock
# Movin' On Down the Line The Black Crowes Warpaint None None 342693 Rock
# Wounded Bird The Black Crowes Warpaint None None 263453 Rock
# Volcano U2 Songs of Innocence None None 194116 Rock
# Wee Who See the Deep The Black Crowes Warpaint None None 290520 Rock
# Cedarwood Road U2 Songs of Innocence None None 265268 Rock
# Locust Street The Black Crowes Warpaint None None 255240 Rock
# Raised By Wolves U2 Songs of Innocence None None 245599 Rock
# The Troubles U2 Songs of Innocence None None 285843 Rock
# This Is Where You Can Reach Me Now U2 Songs of Innocence None None 305134 Rock
# God's Got It The Black Crowes Warpaint None None 202653 Rock
# California (There Is No End to Love) U2 Songs of Innocence None None 239846 Rock
# Every Breaking Wave U2 Songs of Innocence None None 252162 Rock
# Interview With the Onion News Network Onion News Network Onion News Network, Season 1 1 None 302002 Comedy
# Song for Someone U2 Songs of Innocence None None 226763 Rock
# The Miracle (Of Joey Ramone) U2 Songs of Innocence None None 255382 Rock
# Iris (Hold Me Close) U2 Songs of Innocence None None 319457 Rock
# Goodbye Daughters of the Revolution The Black Crowes Warpaint None None 304147 Rock
# Walk Believer Walk The Black Crowes Warpaint None None 280253 Rock
# Choice Hotels International Undercover Boss Undercover Boss, Season 2 1 None 2614047 Reality TV
# Microchip Jason Farnham YouTube Audio Library None None 114336 Dance & Electronic
# Anant Agarwal IEEE Computer Society Computing Conversations None None 494000 Podcast
# For Those About To Rock (We Salute You) AC/DC Who Made Who Rock
# Hells Bells AC/DC Who Made Who Rock
# Shake Your Foundations AC/DC Who Made Who Rock

# %% [markdown]
# # Bonus Worked Example: Twfriends.py (Chapter 15)

# %%
# Keep this file separate

# https://apps.twitter.com/
# Create new App and get the four strings

def oauth():
    return {"consumer_key": "h7Lu...Ng",
            "consumer_secret": "dNKenAC3New...mmn7Q",
            "token_key": "10185562-eibxCp9n2...P4GEQQOSGI",
            "token_secret": "H0ycCFemmC4wyf1...qoIpBo"}

# %%
import urllib.request, urllib.parse, urllib.error
import twurl
import json
import sqlite3
import ssl

TWITTER_URL = 'https://api.twitter.com/1.1/friends/list.json'

conn = sqlite3.connect('friends.sqlite')
cur = conn.cursor()

cur.execute('''CREATE TABLE IF NOT EXISTS People
            (id INTEGER PRIMARY KEY, name TEXT UNIQUE, retrieved INTEGER)''')
cur.execute('''CREATE TABLE IF NOT EXISTS Follows
            (from_id INTEGER, to_id INTEGER, UNIQUE(from_id, to_id))''')

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    acct = input('Enter a Twitter account, or quit: ')
    if (acct == 'quit'): break
    if (len(acct) < 1):
        cur.execute('SELECT id, name FROM People WHERE retrieved=0 LIMIT 1')
        try:
            (id, acct) = cur.fetchone()
        except:
            print('No unretrieved Twitter accounts found')
            continue
    else:
        cur.execute('SELECT id FROM People WHERE name = ? LIMIT 1',
                    (acct, ))
        try:
            id = cur.fetchone()[0]
        except:
            cur.execute('''INSERT OR IGNORE INTO People
                        (name, retrieved) VALUES (?, 0)''', (acct, ))
            conn.commit()
            if cur.rowcount != 1:
                print('Error inserting account:', acct)
                continue
            id = cur.lastrowid

    url = twurl.augment(TWITTER_URL, {'screen_name': acct, 'count': '100'})
    print('Retrieving account', acct)
    try:
        connection = urllib.request.urlopen(url, context=ctx)
    except Exception as err:
        print('Failed to Retrieve', err)
        break

    data = connection.read().decode()
    headers = dict(connection.getheaders())

    print('Remaining', headers['x-rate-limit-remaining'])

    try:
        js = json.loads(data)
    except:
        print('Unable to parse json')
        print(data)
        break

    # Debugging
    # print(json.dumps(js, indent=4))

    if 'users' not in js:
        print('Incorrect JSON received')
        print(json.dumps(js, indent=4))
        continue

    cur.execute('UPDATE People SET retrieved=1 WHERE name = ?', (acct, ))

    countnew = 0
    countold = 0
    for u in js['users']:
        friend = u['screen_name']
        print(friend)
        cur.execute('SELECT id FROM People WHERE name = ? LIMIT 1',
                    (friend, ))
        try:
            friend_id = cur.fetchone()[0]
            countold = countold + 1
        except:
            cur.execute('''INSERT OR IGNORE INTO People (name, retrieved)
                        VALUES (?, 0)''', (friend, ))
            conn.commit()
            if cur.rowcount != 1:
                print('Error inserting account:', friend)
                continue
            friend_id = cur.lastrowid
            countnew = countnew + 1
        cur.execute('''INSERT OR IGNORE INTO Follows (from_id, to_id)
                    VALUES (?, ?)''', (id, friend_id))
    print('New accounts=', countnew, ' revisited=', countold)
    print('Remaining', headers['x-rate-limit-remaining'])
    conn.commit()
cur.close()

# %% [markdown]
# # Worked Example: roster.py (Chapter 15)

# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
cur = conn.cursor()

# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

fname = input('Enter file name: ')
if len(fname) < 1:
    fname = 'roster_data_sample.json'

# [
#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

str_data = open(fname).read()
json_data = json.loads(str_data)

for entry in json_data:

    name = entry[0];
    title = entry[1];

    print((name, title))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id) VALUES ( ?, ? )''',
        ( user_id, course_id ) )

    conn.commit()
# Out:
# Enter file name:
# ('Charley', 'si110')
# ('Mea', 'si110')
# ('Hattie', 'si110')
# ('Lyena', 'si110')
# ('Keziah', 'si110')
# ('Ellyce', 'si110')
# ('Thalia', 'si110')
# ('Meabh', 'si110')
# ('Aria', 'si110')
# ('Reena', 'si110')
# ('Ioannis', 'si110')
# ('Reily', 'si110')
# ('Sidharth', 'si110')
# ('Keiara', 'si110')
# ('Yann', 'si110')
# ('Marykate', 'si110')
# ('Dylan', 'si110')
# ('Kiran', 'si110')
# ('Faizaan', 'si110')
# ('Aneshia', 'si110')
# ('Kamron', 'si110')
# ('Allen', 'si110')
# ('Marshall', 'si110')
# ('Rosa', 'si106')
# ('Nora', 'si106')
# ('Mairin', 'si106')
# ('Zendel', 'si106')
# ('Honie', 'si106')
# ('Betsy', 'si106')
# ('Davie', 'si106')
# ('Larissa', 'si106')
# ('Shaurya', 'si106')
# ('Shania', 'si106')
# ('Sorcha', 'si106')
# ('Jeanna', 'si106')
# ('Temba', 'si106')
# ('Buse', 'si106')
# ('Mohammed', 'si106')
# ('Kayah', 'si106')
# ('Kareena', 'si106')
# ('Dineo', 'si106')
# ('Philippa', 'si106')
# ('Lia', 'si206')
# ('Sharlyn', 'si206')
# ('Linton', 'si206')
# ('Temilade', 'si206')
# ('Areez', 'si206')
# ('MacCartney', 'si206')
# ('Abubakar', 'si206')
# ('Derryn', 'si206')
# ('Elan', 'si206')
# ('Vikki', 'si206')
# ('Anisa', 'si206')
# ('Klevis', 'si206')
# ('Tait', 'si206')
# ('Rhea', 'si206')
# ('Pearsen', 'si206')
# ('Willow', 'si206')
# ('Skye', 'si206')
# ('Caralee', 'si206')
# ('Charlee', 'si206')
# ('Karyn', 'si206')
# ('Elana', 'si206')
# ('Maggie', 'si206')
# ('Eryk', 'si206')
# ('Zulaikha', 'si301')
# ('Elshan', 'si301')
# ('Anastasia', 'si301')
# ('Connar', 'si301')
# ('Anay', 'si301')
# ('Jayla', 'si301')
# ('Cai', 'si301')
# ('Zijie', 'si301')
# ('Riana', 'si301')
# ('Codie', 'si301')
# ('Colette', 'si301')
# ('Lucee', 'si301')
# ('Tatiana', 'si301')
# ('Zhong', 'si301')
# ('Lowri', 'si301')
# ('Maggy', 'si301')
# ('Basher', 'si301')
# ('Tanika', 'si301')
# ('Aria', 'si301')
# ('Belle', 'si301')
# ('Laranya', 'si301')
# ('Dayna', 'si301')
# ('Elleanne', 'si301')
# ('Maanav', 'si310')
# ('Tamta', 'si310')
# ('Frazer', 'si310')
# ('Sacha', 'si310')
# ('Aidan', 'si310')
# ('Abel', 'si310')
# ('Ahtasham', 'si310')
# ('Avinash', 'si310')
# ('Colette', 'si310')
# ('Cohen', 'si310')
# ('Rori', 'si310')
# ('Youer', 'si310')
# ('Jamey', 'si310')
# ('Makenzie', 'si310')
# ('Ida', 'si310')
# ('Alexzander', 'si310')
# ('Kavita', 'si310')
# ('Talia', 'si310')
# ('Anthony', 'si310')
# ('Elona', 'si334')
# ('Inan', 'si334')
# ('Caoilainn', 'si334')
# ('Ainsley', 'si334')
# ('Franciszek', 'si334')
# ('Corrie', 'si334')
# ('Nolan', 'si334')
# ('Makala', 'si334')
# ('Obieluem', 'si334')
# ('Camryn', 'si334')
# ('Honie', 'si334')
# ('Ole', 'si334')
# ('Raine', 'si334')
# ('Tyllor', 'si334')
# ('Diane', 'si334')
# ('Cullen', 'si334')
# ('Taylor', 'si334')
# ('Schekina', 'si334')
# ('Kensey', 'si334')
# ('Zhi', 'si334')
# ('Kiran', 'si334')
# ('Tymoteusz', 'si334')
# ('Windsor', 'si363')
# ('Kashish', 'si363')
# ('Diarmid', 'si363')
# ('Laura', 'si363')
# ('Jaskaran', 'si363')
# ('Presley', 'si363')
# ('Brooklynn', 'si363')
# ('Heddle', 'si363')
# ('Travis', 'si363')
# ('Alx', 'si363')
# ('Airen', 'si363')
# ('Erika', 'si363')
# ('Mackie', 'si363')
# ('Wen', 'si363')
# ('Seaan', 'si363')
# ('Meghan', 'si363')
# ('Ryaan', 'si363')
# ('Imogem', 'si364')
# ('Harlie', 'si364')
# ('Ronnie', 'si364')
# ('Lucca', 'si364')
# ('Shanelle', 'si364')
# ('Ieuan', 'si364')
# ('Anneliese', 'si364')
# ('Simon', 'si364')
# ('Sorche', 'si364')
# ('Nawal', 'si364')
# ('Adelaide', 'si364')
# ('Rhia', 'si364')
# ('Katarzyna', 'si364')
# ('LLeyton', 'si364')
# ('Enzo', 'si364')
# ('Declan', 'si364')
# ('Emelie', 'si364')
# ('Baillie', 'si364')
# ('Shola', 'si364')
# ('Jenna', 'si422')
# ('Miles', 'si422')
# ('Sakina', 'si422')
# ('Melanie', 'si422')
# ('Bailie', 'si422')
# ('Cassy', 'si422')
# ('Nikash', 'si422')
# ('Hebe', 'si422')
# ('Sia', 'si422')
# ('Skyla', 'si422')
# ('Jamaal', 'si422')
# ('Keanna', 'si422')
# ('Vanya', 'si422')
# ('Temperance', 'si422')
# ('Hafiza', 'si422')
# ('Alx', 'si422')
# ('Brigitte', 'si422')
# ('Eliana', 'si422')
# ('Kayden', 'si422')
# ('Man', 'si422')
# ('Jaydyn', 'si422')
# ('Soukina', 'si430')
# ('Stephenjunior', 'si430')
# ('Buddy', 'si430')
# ('Holly', 'si430')
# ('Kamilia', 'si430')
# ('Cassie', 'si430')
# ('Kris', 'si430')
# ('Maia', 'si430')
# ('Abel', 'si430')
# ('Tamika', 'si430')
# ('Deano', 'si430')
# ('Rosa', 'si430')
# ('Georgia', 'si430')
# ('Louie', 'si430')
# ('Kassie', 'si430')
# ('Mutinta', 'si430')
# ('Manwen', 'si430')

# %% [markdown]
# # Week 4 Assignment:  Many Students in Many Courses

# %%
import json
import sqlite3

conn = sqlite3.connect('rosterdb.sqlite')
cur = conn.cursor()

# Do some setup
cur.executescript('''
DROP TABLE IF EXISTS User;
DROP TABLE IF EXISTS Member;
DROP TABLE IF EXISTS Course;

CREATE TABLE User (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name   TEXT UNIQUE
);

CREATE TABLE Course (
    id     INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    title  TEXT UNIQUE
);

CREATE TABLE Member (
    user_id     INTEGER,
    course_id   INTEGER,
    role        INTEGER,
    PRIMARY KEY (user_id, course_id)
)
''')

fname = input('Enter file name: ')
if len(fname) < 1:
    fname = 'roster_data.json'

# [
#   [ "Charley", "si110", 1 ],
#   [ "Mea", "si110", 0 ],

str_data = open(fname).read()
json_data = json.loads(str_data)

for entry in json_data:

    name = entry[0];
    title = entry[1];
    role = entry[2]

    print((name, title, role))

    cur.execute('''INSERT OR IGNORE INTO User (name)
        VALUES ( ? )''', ( name, ) )
    cur.execute('SELECT id FROM User WHERE name = ? ', (name, ))
    user_id = cur.fetchone()[0]

    cur.execute('''INSERT OR IGNORE INTO Course (title)
        VALUES ( ? )''', ( title, ) )
    cur.execute('SELECT id FROM Course WHERE title = ? ', (title, ))
    course_id = cur.fetchone()[0]

    cur.execute('''INSERT OR REPLACE INTO Member
        (user_id, course_id, role) VALUES ( ?, ?, ? )''',
        ( user_id, course_id, role ) )
    
    conn.commit()
    
    
sqlstr = 'SELECT hex(User.name || Course.title || Member.role ) AS X FROM User JOIN Member JOIN Course ON User.id = Member.user_id AND Member.course_id = Course.id ORDER BY X'

for row in cur.execute(sqlstr) :
    print (str(row[0]))

cur.close()
# Out:
# Enter file name:
# ('Angeline', 'si110', 1)
# ('Calypso', 'si110', 0)
# ('Shani', 'si110', 0)
# ('Maciej', 'si110', 0)
# ('Rea', 'si110', 0)
# ('Husnain', 'si110', 0)
# ('Aronas', 'si110', 0)
# ('Fathma', 'si110', 0)
# ('Darius', 'si110', 0)
# ('Kaeli', 'si110', 0)
# ('Anish', 'si110', 0)
# ('Victory', 'si110', 0)
# ('Cailyne', 'si110', 0)
# ('Libby', 'si110', 0)
# ('Peggy', 'si110', 0)
# ('Meshach', 'si110', 0)
# ('Melissande', 'si110', 0)
# ('Lomond', 'si106', 1)
# ('Kiran', 'si106', 0)
# ('Zachariya', 'si106', 0)
# ('Vanni', 'si106', 0)
# ('Raya', 'si106', 0)
# ('Caoilainn', 'si106', 0)
# ('Aliesha', 'si106', 0)
# ('Tobie', 'si106', 0)
# ('Hanna', 'si106', 0)
# ('Aleeshmah', 'si106', 0)
# ('Joude', 'si106', 0)
# ('Austen', 'si106', 0)
# ('Laurence', 'si106', 0)
# ('Colin', 'si106', 0)
# ('Jenifer', 'si106', 0)
# ('Rio', 'si106', 0)
# ('Ciann', 'si106', 0)
# ('Asal', 'si206', 1)
# ('Colt', 'si206', 0)
# ('Jiao', 'si206', 0)
# ('Lorne', 'si206', 0)
# ('Connie', 'si206', 0)
# ('Daood', 'si206', 0)
# ('Jadon', 'si206', 0)
# ('Shayne', 'si206', 0)
# ('Baron', 'si206', 0)
# ('Eryn', 'si206', 0)
# ('Ming', 'si206', 0)
# ('Allegria', 'si206', 0)
# ('Sionan', 'si206', 0)
# ('Kole', 'si206', 0)
# ('Uxia', 'si206', 0)
# ('Kennedi', 'si206', 0)
# ('Calla', 'si206', 0)
# ('Zeid', 'si206', 0)
# ('Arman', 'si206', 0)
# ('Elli', 'si206', 0)
# ('Ceitidh', 'si206', 0)
# ('Oliwier', 'si206', 0)
# ('Elora', 'si206', 0)
# ('Dewi', 'si206', 0)
# ('Billy', 'si206', 0)
# ('Shinade', 'si206', 0)
# ('Anais', 'si206', 0)
# ('Kayne', 'si206', 0)
# ('Ashlyn', 'si206', 0)
# ('Hena', 'si301', 1)
# ('Abhinav', 'si301', 0)
# ('Darragh', 'si301', 0)
# ('Sakina', 'si301', 0)
# ('Ragen', 'si422', 0)
# ('Iniobong', 'si422', 0)
# ('Saicu', 'si422', 0)
# ('Roxanna', 'si422', 0)
# ('Cameron', 'si422', 0)
# ('Symon', 'si422', 0)
# ('Zuhrah', 'si422', 0)
# ('Dylin', 'si422', 0)
# ('Tamzin', 'si422', 0)
# ('Rikki', 'si422', 0)
# ('Juan', 'si422', 0)
# ('Ayleen', 'si422', 0)
# ('Coleen', 'si422', 0)
# ('Maxwell', 'si422', 0)
# ('Mikael', 'si422', 0)
# ('Berkay', 'si422', 0)
# ('Alan', 'si422', 0)
# ('Hadjar', 'si430', 1)
# ('Aamirah', 'si430', 0)
# ('Kofi', 'si430', 0)
# ('Elsa', 'si430', 0)
# ('Asrar', 'si430', 0)
# ('Nakeisha', 'si430', 0)
# ('Jaxon', 'si430', 0)
# ('Zoe', 'si430', 0)
# ('Cieran', 'si430', 0)
# ('Griffyn', 'si430', 0)
# ('Francesca', 'si430', 0)
# ('Boedyn', 'si430', 0)
# ('Nirvana', 'si430', 0)
# ('Mati', 'si430', 0)
# ('Sareena', 'si430', 0)
# ('Zaheerah', 'si430', 0)
# ('Likiesha', 'si430', 0)
# ('Nash', 'si430', 0)
# ('Ayan', 'si430', 0)
# ('Carra', 'si430', 0)
# ('Victor', 'si430', 0)
# ('Hadyn', 'si430', 0)
# ('Jodie', 'si430', 0)
# 41616D69726168736934333030
# 416172726F6E736933303130
# 416172726F6E736933313030
# 416264756C736933363430
# 416268696E6176736933303130
# 41647269616E736933303130
# 41696461736934323230
# 41696C69736934323230
# 416C616E736934323230
# 416C6563736933363430
# 416C656573686D6168736931303630
# 416C656B73616E646172736933313030
# 416C6965736861736931303630
# 416C69737361736933303130
# 416C6973746172736933363430
# 416C6C6567726961736932303630
# 416C6C6569736861736933303130
# 416C6C69736861736933363430
# 416C736933363331
# 416C7965737361736933363430
# 416D616E736934323230
# 416D696565736933363430
# 416E616973736932303630
# 416E67616C69736933363430
# 416E67656C696E65736931313031
# 416E697368736931313030
# 416F696665736933313030
# 417261666174736933313030
# 41726D616E736932303630
# 41726D656C6C65736933333430
# 41726F6E6173736931313030
# 417279616E736933333430
# 4173616C736932303631
# 4173686C796E736932303630
# 4173686E61736933313030
# 41736877696E736933363430
# 4173726172736934333030
# 41737261736933333430
# 417374726964736934323230
# 41757374656E736931303630
# 4179616E736934333030
# 41796C61736933303130
# 41796C65656E736934323230
# 41797365736933303130
# 4261626174756E6D697365736934323230
# 4261726F6E736932303630
# 42617965736933363330
# 426572616B61736933303130
# 4265726B6179736934323230
# 426861616C6465656E736933333430
# 42696C6C79736932303630
# 426F6564796E736934333030
# 426F6764616E736933363430
# 426F73687261736934323230
# 4272796F6E79736934323230
# 4361636965736933333430
# 4361696C65616E736933363430
# 4361696C796E65736931313030
# 4361696E736933363430
# 43616C65616E736934323230
# 43616C6C61736932303630
# 43616C7970736F736931313030
# 43616D65726F6E736934323230
# 43616F696C61696E6E736931303630
# 4361727261736934333030
# 436172736F6E736934323230
# 4365697261736933303130
# 43656974696468736932303630
# 4D616E6D6F68616E736934323230
# 4D617269616E736933363430
# 4D6172696F6E736933363430
# 4D61726C6579736933313030
# 4D617274696E61736933303130
# 4D61746961736933363430
# 4D6174696C6461736934323230
# 4D617469736934333030
# 4D617877656C6C736934323230
# 4D656C697373616E6465736931313030
# 4D656E6E61736933313030
# 4D657368616368736931313030
# 4D696368656C61736933303130
# 4D696775656C736933313030
# 4D696B61656C736934323230
# 4D696C6F73736933333430
# 4D696E67736932303630
# 4D6F6F7361736933303130
# 4E616B6569736861736934333030
# 4E616F6D69736933303130
# 4E617368736934333030
# 4E656C6C736933313030
# 4E69616D68736933363430
# 4E69636F64656D7573736933313030
# 4E697276616E61736934333030
# 4E6F6C616E736933363430
# 4E7572736934323230
# 4E757761697261736933333430
# 4E796F6D69736933303130
# 4F626F7361736933313030
# 4F6B656F6768656E65736933333430
# 4F6C69766572736933333430
# 4F6C6976696572736933313030
# 4F6C6977696572736932303630
# 4F6C75776164656D696C616465736933333430
# 4F727269636B736933363330
# 5061726465657072616A736933363430
# 5065617273656E736933333430
# 5065676779736931313030
# 5072696E6179736933333430
# 5072696E6179736933363430
# 50756A61736933363330
# 526167656E736934323230
# 52616A61736934323230
# 52616D616E6173736933313030
# 526176696E736933363430
# 52617961736931303630
# 5261796E61736933363431
# 526561736931313030
# 52656765616E736933313030
# 52656D79736933363430
# 526875616E736933333430
# 52696B6B69736934323230
# 52696F736931303630
# 526F6D696E61736933313030
# 526F726965736933333430
# 526F78616E6E61736934323230
# 5361696375736934323230
# 53616B696E61736933303130
# 53616C6D616E736933363330
# 53616D696861736933363330
# 53617265656E61736934333030
# 536176616E6168736933313030
# 53686165736933363430
# 5368616E69736931313030
# 536861796E65736932303630
# 5368696E616465736932303630
# 536964646861727468736933333430
# 53696F6E616E736932303630
# 536F6E6E697661736933363430
# 53746566616E6F736933363430
# 53746566666965736933303130
# 537465766965736933333430
# 53796D6F6E736934323230
# 54616C6F6E736933333430
# 54616D696B61736933363430
# 54616D7A696E736934323230
# 5461797965736933313030
# 5469626574736934323230
# 546F626965736931303630
# 5479736F6E736933333430
# 55786961736932303630
# 557A6D61736934323230
# 56616E6E69736931303630
# 566963746F72736934333030
# 566963746F7279736931313030
# 56696E6365736934323230
# 57696E64736F72736933303130
# 59616E677869736933333430
# 5961736972736933363330
# 5961736D696E65736933313030
# 5975736933333430
# 5A6163686172697961736931303630
# 5A61686565726168736934333030
# 5A616B6972736933363430
# 5A617261736933363330
# 5A61796E736933303130
# 5A656964736932303630
# 5A69736933303130
# 5A6F65736934333030
# 5A7568726168736934323230

# %% [markdown]
# ***End of week 4 and Chapter 15***

# %% [markdown]
# **Now complex and multi-step data analysis will be started**

# %% [markdown]
# **If you are stuck and don't understand any part than I will recomand you to startover**

# %% [markdown]
# ***Good Luck on Ch 16 - week 5***

# %% [markdown]
# # Geocoding (Example: Google Map API)

# %% [markdown]
# **Geolead.py**

# %%
import urllib.request, urllib.parse, urllib.error
import http
import sqlite3
import json
import time
import ssl
import sys

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSyCYDQ2QYZckoDolhW_i0TQTuPBXcLiLWrU'

if api_key is False:
    api_key = 42
    serviceurl = "http://py4e-data.dr-chuck.net/json?"
else :
    serviceurl = "https://maps.googleapis.com/maps/api/geocode/json?"

# Additional detail for urllib
# http.client.HTTPConnection.debuglevel = 1

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

fh = open("where.data")
count = 0
for line in fh:
    if count > 200 :
        print('Retrieved 200 locations, restart to retrieve more')
        break

    address = line.strip()
    print('')
    cur.execute("SELECT geodata FROM Locations WHERE address= ?",
        (memoryview(address.encode()), ))

    try:
        data = cur.fetchone()[0]
        print("Found in database ",address)
        continue
    except:
        pass

    parms = dict()
    parms["address"] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters', data[:20].replace('\n', ' '))
    count = count + 1

    try:
        js = json.loads(data)
    except:
        print(data)  # We print in case unicode causes an error
        continue

    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') :
        print('==== Failure To Retrieve ====')
        print(data)
        break

    cur.execute('''INSERT INTO Locations (address, geodata)
            VALUES ( ?, ? )''', (memoryview(address.encode()), memoryview(data.encode()) ) )
    conn.commit()
    if count % 10 == 0 :
        print('Pausing for a bit...')
        time.sleep(5)

print("Run geodump.py to read the data from the database so you can vizualize it on a map.")
# Out:
# Found in database  AGH University of Science and Technology
#
# Found in database  Academy of Fine Arts Warsaw Poland
#
# Found in database  American University in Cairo
#
# Found in database  Arizona State University
#
# Found in database  Athens Information Technology
#
# Found in database  BITS Pilani
#
# Found in database  Babcock University
#
# Found in database  Banaras Hindu University
#
# Found in database  Bangalore University
#
# Found in database  Baylor University
#
# Found in database  Beijing normal university
#
# Found in database  Belarusian State University
#
# Found in database  Belgrade University
#
# Found in database  Beloit College
#
# Found in database  Belorussian State University
#
# Found in database  Ben Gurion University
#
# Found in database  Bharthidasan University
#
# Found in database  Boston University
#
# Found in database  California Polytechnic State University of San Luis Obispo
#
# Found in database  California State University San Bernardino
#
# Found in database  City of Westminster College
#
# Found in database  Columbia University
#
# Found in database  Cranfield University
#
# Found in database  Czech Technical University in Prague
#
# Found in database  Dartmouth
#
# Found in database  De Anza College
#
# Found in database  Distant University of Hagen
#
# Found in database  Dnipropetrovsk National University
#
# Found in database  Dokuz Eylul University
#
# Found in database  Drexel
#
# Found in database  Drexel University and University of Texas at Austin
#
# Found in database  Duke University
#
# Found in database  EM Lyon
#
# Found in database  Ecole centrale de PARIS
#
# Found in database  Elon University
#
# Found in database  Erhvervsakademi Sydvest
#
# Found in database  Escuela Superior Politecnica del Litoral
#
# Found in database  Fachhochschule Dusseldorf
#
# Found in database  Fachhochschule FH Salzburg
#
# Found in database  Faculdade de Tecnologia do Estado de Sao Paulo
#
# Found in database  Faculty of Technical Sciences Novi Sad Serbia
#
# Found in database  Farmingdale State University
#
# Found in database  Federal University of Minas Gerais
#
# Found in database  Florida Atlantic University
#
# Found in database  Franklin Pierce College
#
# Found in database  Gauhati University
#
# Found in database  George Mason University
#
# Found in database  Georgetown University Law Center
#
# Found in database  Georgia State University
#
# Found in database  Grandville
#
# Found in database  Groep T University
#
# Found in database  Hanoi University of Science and Technology
#
# Found in database  Hebrew University
#
# Found in database  IIIT Hyderabad
#
# Found in database  IIT KANPUR
#
# Found in database  IT College of Estonia
#
# Found in database  IU
#
# Found in database  IUAV Venezia
#
# Found in database  Illinois Institute of Technology
#
# Found in database  Illinois State University Joliet Junior College
#
# Found in database  Indian Institute of Technology
#
# Found in database  Indian Institute of Technology Kharagpur India
#
# Found in database  Indian School of Mines Dhanbad
#
# Found in database  Indiana University
#
# Found in database  Indiana University at Bloomington
#
# Found in database  Institut Superieur de technologies
#
# Found in database  Institute of Business and Modern Technologies
#
# Found in database  Instituto Tecnologico de Santo Domingo
#
# Found in database  International Institute of Information Technology Hyderabad
#
# Found in database  Irkutsk State University
#
# Found in database  JADAVPUR UNIVERSITY
#
# Found in database  Jawaharlal Nehru Technological University
#
# Found in database  Jawaharlal Nehru University
#
# Found in database  Jordan University of Science and Technology
#
# Found in database  K-State
#
# Found in database  KUL
#
# Found in database  Kalamazoo College
#
# Found in database  Kaunas Technology University
#
# Found in database  Kaunas university of technology
#
# Found in database  Kazan Federal University
#
# Found in database  Kent State University
#
# Found in database  Kharkiv State Academy of Municipal Economy Ukraine
#
# Found in database  King Mongkuts University of Technology Thonburi
#
# Found in database  Kokshetau Institute of Economics and Management
#
# Found in database  Kyiv Polytechnic Institute
#
# Found in database  Kyiv Polytechnical Institute
#
# Found in database  Kyiv Unisersity of Oriental Language
#
# Found in database  Laurentian University
#
# Found in database  Lisandro Alvarado
#
# Found in database  Lodz University of Technology
#
# Found in database  Lviv University
#
# Found in database  MSU
#
# Found in database  Madras university
#
# Found in database  Magnitogorsk State Technical University
#
# Found in database  Malayer Azad University
#
# Found in database  Marietta College
#
# Found in database  Masdar Institute
#
# Found in database  Matematicki fakultet Beograd
#
# Found in database  Michigan State University
#
# Found in database  Middle East Technical University
#
# Found in database  Missouri University of Science and Technology
#
# Found in database  Monash
#
# Found in database  Monash University
#
# Found in database  Monash University Churchill Australia
#
# Found in database  Monterrey Institute of Technology and Higher Education
#
# Found in database  Moscow Engineering-Physics Institute
#
# Found in database  Moscow Institute of Physics & Technology
#
# Found in database  Moscow State University
#
# Found in database  NIT ROURKELA
#
# Found in database  NYU
#
# Found in database  Nagpur University
#
# Found in database  Nanyang Technological University
#
# Found in database  National Institute of Technology Jalandhar
#
# Found in database  National Taiwan University
#
# Found in database  National University of Engineering
#
# Found in database  North Central College
#
# Found in database  Northeastern University
#
# Found in database  Northwestern University
#
# Found in database  Obninsk Technical University of Nuclear Power Engineering Russia
#
# Found in database  Old Dominion University
#
# Found in database  Oregon Institute of Technology
#
# Found in database  PUCMM
#
# Found in database  Payame Noor University
#
# Found in database  Penn State University
#
# Found in database  Politecnico di Milano
#
# Found in database  Politehnica University Bucharest
#
# Found in database  Polytechnic University of Timisoara
#
# Found in database  Pondicherry University
#
# Found in database  Pontificia universidad catolica de chile
#
# Found in database  Portland State University
#
# Found in database  Purdue University Indianapolis
#
# Found in database  R V College of Engineering
#
# Found in database  RPI
#
# Found in database  Ramapo College of New Jersey
#
# Found in database  Rochester Institute of Technology
#
# Found in database  SASTRA University
#
# Found in database  Saint Petersburg State University
#
# Found in database  Saint Petersburg State University of Aerospace Instrumentation
#
# Found in database  Saint-Petersburg Polytechnic Univesity
#
# Found in database  San Francisco State University
#
# Found in database  San Jose State University
#
# Found in database  Shanghai Jiao Tong University
#
# Found in database  Sharif University of Technology
#
# Found in database  Simon Bolivar University
#
# Found in database  Simon Fraser University
#
# Found in database  Smolensk State University
#
# Found in database  Sonoma State University
#
# Found in database  South Federal University
#
# Found in database  Spiru Haret University
#
# Found in database  Stanford
#
# Found in database  State University of Campinas
#
# Found in database  State University of New York College at Oswego
#
# Found in database  Stellenbosch University
#
# Found in database  Stonehill College
#
# Found in database  Tallinn University
#
# Found in database  Tallinn University of Technology
#
# Found in database  Tampere University of Technology
#
# Found in database  Tanta University
#
# Found in database  Tarrant County College
#
# Found in database  Technical University of Cluj-Napoca
#
# Found in database  Technion
#
# Found in database  Tel Aviv University
#
# Found in database  The Jerusalem collage of engineering
#
# Found in database  The University of Latvia
#
# Found in database  The University of Manchester
#
# Found in database  The University of South Africa
#
# Found in database  Transilvania University
#
# Found in database  Tufts University
#
# Found in database  UC Berkeley
#
# Found in database  UCLA
#
# Found in database  UCSD
#
# Found in database  UIUC
#
# Found in database  UMD
#
# Found in database  UNISA
#
# Found in database  UNIVERSIDAD DE Buenos Aires
#
# Found in database  UOC
#
# Found in database  USC
#
# Found in database  UW Madison
#
# Found in database  Universidad Central de Venezuela
#
# Found in database  Universidad Complutense de Madrid
#
# Found in database  Universidad Cooperativa de Colombia
#
# Found in database  Universidad Nacional Autonoma de Mexico
#
# Found in database  Universidad Nacional Costa Rica
#
# Found in database  Universidad Nacional de Colombia
#
# Found in database  Universidad Tecnologica Boliviana
# Found in database  Universidad de Buenos Aires
#
# Found in database  Universidad de Castilla La Mancha
#
# Found in database  Universidad de Los Andes Colombia
#
# Found in database  Universidad de Oriente
#
# Found in database  Universidad de San Carlos de Guatemala
#
# Found in database  Universidad de Valladolid
#
# Found in database  Universidad de la Sabana
#
# Found in database  Universidad del Valle de Guatemala
#
# Found in database  Universidade Federal da Paraiba
#
# Found in database  Universidade Federal de Santa Catarina
#
# Found in database  Universidade Federal do Rio Grande do Sul
#
# Found in database  Universidade Federal do Rio de Janeiro
#
# Found in database  Universidade Tecnica de Lisboa
#
# Found in database  Universidade de Sao Paulo
#
# Found in database  Universidade do Minho
#
# Found in database  Universitas Gadjah Mada
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universitat+Politecnica+de+Valencia&key=42
# Retrieved 2118 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universite+Catholique+de+Louvain&key=42
# Retrieved 2425 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+College+Dublin&key=42
# Retrieved 1687 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+Munich&key=42
# Retrieved 2271 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Akron&key=42
# Retrieved 2115 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Alberta&key=42
# Retrieved 2016 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Amsterdam&key=42
# Retrieved 2050 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Arkansas&key=42
# Retrieved 2033 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Athens&key=42
# Retrieved 1625 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Belgrade&key=42
# Retrieved 1944 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Birmingham&key=42
# Retrieved 1792 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Cambridge&key=42
# Retrieved 2126 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Central+Oklahoma&key=42
# Retrieved 2270 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Chicago&key=42
# Retrieved 2457 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Cincinnati&key=42
# Retrieved 2298 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Colorado+at+Boulder&key=42
# Retrieved 1800 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Connecticut&key=42
# Retrieved 1794 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Dallas&key=42
# Retrieved 2266 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Debrecen&key=42
# Retrieved 1711 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Delaware&key=42
# Retrieved 3871 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Erlangen-Nuremberg&key=42
# Retrieved 2263 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Essex&key=42
# Retrieved 1992 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Evora&key=42
# Retrieved 1927 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Florida&key=42
# Retrieved 1805 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Gothenburg&key=42
# Retrieved 4055 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Greifswald&key=42
# Retrieved 1910 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Hamburg&key=42
# Retrieved 1787 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Hawaii&key=42
# Retrieved 2268 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Helsinki&key=42
# Retrieved 1720 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Ilorin+Kwara+State&key=42
# Retrieved 2037 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Jaffna&key=42
# Retrieved 2016 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Kansas&key=42
# Retrieved 2125 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Kerala&key=42
# Retrieved 2306 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+London&key=42
# Retrieved 4529 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Malaga&key=42
# Retrieved 2084 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Malaya&key=42
# Retrieved 1917 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Manchester&key=42
# Retrieved 1966 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Michigan&key=42
# Retrieved 2120 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Missouri+-+Columbia&key=42
# Retrieved 1798 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Moratuwa&key=42
# Retrieved 1990 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Mumbai&key=42
# Retrieved 2825 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Nebraska&key=42
# Retrieved 2096 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Nebraska+-+Lincoln&key=42
# Retrieved 2096 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+New+Haven&key=42
# Retrieved 2138 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+New+South+Wales&key=42
# Retrieved 1805 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Notre+Dame&key=42
# Retrieved 1812 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Oklahoma&key=42
# Retrieved 2113 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Ottawa&key=42
# Retrieved 2312 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Oxford&key=42
# Retrieved 1773 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Padua&key=42
# Retrieved 2294 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Pavia+Italy&key=42
# Retrieved 2301 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Pennsylvania&key=42
# Retrieved 1826 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Piraeus+Athens&key=42
# Retrieved 1916 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Pretoria&key=42
# Retrieved 2222 characters {    "results" : [
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Salamanca&key=42
# Retrieved 1785 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Sao+Paulo&key=42
# Retrieved 1703 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Sarajevo&key=42
# Retrieved 2214 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Southern+California&key=42
# Retrieved 2014 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Stellenbosch&key=42
# Retrieved 1903 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Tartu&key=42
# Retrieved 1906 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Tehran&key=42
# Retrieved 1678 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Texas&key=42
# Retrieved 1782 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Texas+at+Austin&key=42
# Retrieved 1782 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Toronto&key=42
# Retrieved 2322 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Tuebingen&key=42
# Retrieved 2175 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Twente&key=42
# Retrieved 2108 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Utah&key=42
# Retrieved 2145 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Vienna&key=42
# Retrieved 2094 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Warsaw&key=42
# Retrieved 2331 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Washington&key=42
# Retrieved 2270 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Washington+-+Bothell&key=42
# Retrieved 2270 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Waterloo&key=42
# Retrieved 4260 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+West+Florida&key=42
# Retrieved 2340 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+Wisconsin&key=42
# Retrieved 1642 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+the+Punjab+Lahore&key=42
# Retrieved 2213 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=University+of+the+Witwatersrand&key=42
# Retrieved 2392 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Vilnius+Gediminas+Technical+University&key=42
# Retrieved 2142 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Vilnius+University&key=42
# Retrieved 2143 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Virginia+Commonwealth+University&key=42
# Retrieved 1952 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Virginia+Tech&key=42
# Retrieved 1822 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Viswakarma+Institute+Pune+India&key=42
# Retrieved 4609 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Warsaw+University&key=42
# Retrieved 2331 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Washington+State+University&key=42
# Retrieved 1749 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Wayne+State&key=42
# Retrieved 1921 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Weber+State&key=42
# Retrieved 2109 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Weizmann+Institute+of+Science&key=42
# Retrieved 1919 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Western+Governors+University&key=42
# Retrieved 2270 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Xavier+University&key=42
# Retrieved 2295 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Zagazig+University&key=42
# Retrieved 2125 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=allama+iqbal+open+university+islamabad&key=42
# Retrieved 2912 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=arizona+state+university&key=42
# Retrieved 2291 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=federal+institute+of+tecnology+and+education+from+southeastern+Minas+Gerais&key=42
# Retrieved 1644 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=kansas+state+university&key=42
# Retrieved 1793 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=universidad+complutense+de+madrid&key=42
# Retrieved 2088 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=university+of+Patras&key=42
# Retrieved 1651 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=university+of+padua&key=42
# Retrieved 2325 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Daffodil+International+University&key=42
# Retrieved 2176 characters {    "results" : [
# Run geodump.py to read the data from the database so you can vizualize it on a map.

# %% [markdown]
# ***You have to run the geodump.py program file to do the rest of the program.***

# %% [markdown]
# **Geodump.py**

# %%
import sqlite3
import json
import codecs

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('SELECT * FROM Locations')
fhand = codecs.open('where.js', 'w', "utf-8")
fhand.write("myData = [\n")
count = 0
for row in cur :
    data = str(row[1].decode())
    try: js = json.loads(str(data))
    except: continue

    if not('status' in js and js['status'] == 'OK') : continue

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    if lat == 0 or lng == 0 : continue
    where = js['results'][0]['formatted_address']
    where = where.replace("'", "")
    try :
        print(where, lat, lng)

        count = count + 1
        if count > 1 : fhand.write(",\n")
        output = "["+str(lat)+","+str(lng)+", '"+where+"']"
        fhand.write(output)
    except:
        continue

fhand.write("\n];\n")
cur.close()
fhand.close()
print(count, "records written to where.js")
print("Open where.html to view the data in a browser")
# Out:
# aleja Adama Mickiewicza 30, 30-059 Kraków, Poland 50.06688579999999 19.9136192
# Krakowskie Przedmieście 5, 00-068 Warszawa, Poland 52.2394019 21.0150792
# AUC Avenue، Road، First New Cairo, Cairo Governorate 11835, Egypt 30.018923 31.499674
# 411 N Central Ave, Phoenix, AZ 85004, USA 33.5074106 -112.0650182
# 2500 Daniells Bridge Rd #300, Athens, GA 30606, USA 33.9094132 -83.4603953
# Vidya Vihar, Pilani, Rajasthan 333031, India 28.3588163 75.58802039999999
# Ilishan-Remo, Nigeria 6.8939569 3.7187158
# Cidade Universitária Zeferino Vaz - Barão Geraldo, Campinas - SP, 13083-970, Brazil -22.8184393 -47.0647206
# 7060 NY-104, Oswego, NY 13126, USA 43.45139280000001 -76.5425285
# Stellenbosch Central, Stellenbosch, South Africa -33.9328078 18.864447
# 320 Washington St, North Easton, MA 02357, USA 42.0590153 -71.0806276
# Narva maantee 25, 10120 Tallinn, Estonia 59.4387321 24.7713836
# Ehitajate tee 5, 12616 Tallinn, Estonia 59.3959451 24.6710596
# Korkeakoulunkatu 7 Kampusareena, 33720 Tampere, Finland 61.4498286 23.8589986
# El-Gaish, Tanta Qism 2, Tanta, Gharbia Governorate, Egypt 30.7924391 30.9991409
# 1500 Houston St, Fort Worth, TX 76102, USA 32.7474661 -97.3278753
# Strada Memorandumului 28, Cluj-Napoca 400114, Romania 46.769299 23.585613
# Praediniussingel 10, 9711 AG Groningen, Netherlands 53.2133951 6.5608166
# Tel Aviv-Yafo, Israel 32.1133141 34.8043877
# Velachery Main Rd, Narayanapuram, Pallikaranai, Chennai, Tamil Nadu 600100, India 12.9452892 80.207843
# Raiņa bulvāris 19, Centra rajons, Rīga, LV-1586, Latvia 56.95080979999999 24.1163132
# Oxford Rd, Manchester M13 9PL, UK 53.4668498 -2.2338837
# Preller St, Muckleneuk, Pretoria, 0002, South Africa -25.7676604 28.1992624
# 300 N Broadway, Lexington, KY 40508, USA 38.0516801 -84.49334189999999
# 419 Boston Ave, Medford, MA 02155, USA 42.4074843 -71.1190232
# Berkeley, CA, USA 37.8718992 -122.2585399
# Los Angeles, CA 90095, USA 34.068921 -118.4451811
# 9500 Gilman Dr, La Jolla, CA 92093, USA 32.8800604 -117.2340135
# Champaign, IL, USA 40.1019523 -88.2271615
# College Park, MD 20742, USA 38.9853283 -76.94943479999999
# 7400 E Arapahoe Rd # 10, Centennial, CO 80112, USA 39.5944197 -104.9024568
# Viamonte 430, C1053 CABA, Argentina -34.5998875 -58.37306949999999
# 101 Regent Ct, State College, PA 16801, USA 40.785354 -77.8227563
# 900 W 34th St, Los Angeles, CA 90007, USA 34.0235782 -118.2865012
# Madison, WI, USA 43.076592 -89.4124875
# Caracas, Capital District, Venezuela 10.4883502 -66.8891696
# Av. Séneca, 2, 28040 Madrid, Spain 40.4375731 -3.7252231
# Calle 30, Santa Marta, Magdalena, Colombia 11.2234838 -74.1708905
# University City, Coyoacán, 04510 Mexico City, CDMX, Mexico 19.3228313 -99.18657739999999
# Avenida 1, Calle 9 Heredia 86, Heredia, 3000, Costa Rica 9.9986898 -84.11118979999999
# Cra 45, Bogotá, Colombia 4.6381938 -74.08404639999999
# Calle Colombia 154, La Paz, Bolivia -16.500656 -68.134299
# Viamonte 430, C1053 CABA, Argentina -34.5998875 -58.37306949999999
# Rectorado UCLM, Calle Altagracia, 50, 13001 Ciudad Real, Cdad. Real, Spain 38.9934998 -3.9254365
# Edificio SD, Cl. 21 #1 – 20, Bogotá, Colombia 4.604375800000001 -74.0659058
# Universidad de Oriente, Avenida 21 Oriente 1816, Zona Sin Asignación de Nombre de Col 39, Azcarate, 72501 Puebla, Pue., Mexico 19.0303925 -98.1903494
# Gainesville, FL 32611, USA 29.6436325 -82.3549302
# 405 30 Gothenburg, Sweden 57.6981719 11.971878
# Domstraße 11, 17489 Greifswald, Germany 54.0949653 13.374584
# 20146 Hamburg, Germany 53.5665641 9.984619499999999
# 2500 Campus Rd, Honolulu, HI 96822, USA 21.296939 -157.8171118
# Yliopistonkatu 4, 00100 Helsinki, Finland 60.1726348 24.9510419
# No C2, Studiopedia, Off Ministry of Health, Fate Tanke Rd, behind Lgea Primary School, Ilorin, Nigeria 8.4928414 4.5962225
# Sir. Pon, Ramanathan Rd, Jaffna, Sri Lanka 9.684855599999999 80.0220413
# 1450 Jayhawk Blvd, Lawrence, KS 66045, USA 38.9543439 -95.2557961
# University of Kerala Senate House Campus, Palayam, Thiruvananthapuram, Kerala 695034, India 8.5032375 76.9473306
# Senate House, Malet St, Bloomsbury, London WC1E 7HU, UK 51.5229378 -0.1308206
# Av. de Cervantes, 2, 29016 Málaga, Spain 36.7199495 -4.4161391
# Jalan Universiti, 50603 Kuala Lumpur, Wilayah Persekutuan Kuala Lumpur, Malaysia 3.1209046 101.6538414
# Oxford Rd, Manchester M13 9PL, UK 53.4668498 -2.2338837
# 500 S State St, Ann Arbor, MI 48109, USA 42.2780436 -83.7382241
# Columbia, MO 65211, USA 38.9403808 -92.32773750000001
# Bandaranayake Mawatha, Moratuwa 10400, Sri Lanka 6.7951275 79.900787
# Mahatma Gandhi Road, Kolivery Village, University of Mumbai,Vidya Nagari, Kala Ghoda, Fort, Mumbai, Maharashtra 400032, India 18.9293321 72.8310376
# 1400 R St, Lincoln, NE 68588, USA 40.8201966 -96.70047629999999
# 1400 R St, Lincoln, NE 68588, USA 40.8201966 -96.70047629999999
# 300 Boston Post Rd, West Haven, CT 06516, USA 41.2907061 -72.9615183
# Sydney NSW 2052, Australia -33.917347 151.2312675
# Notre Dame, IN 46556, USA 41.7055716 -86.2353388
# 660 Parrington Oval, Norman, OK 73019, USA 35.2058936 -97.4457137
# 75 Laurier Ave E, Ottawa, ON K1N 6N5, Canada 45.42310639999999 -75.68313289999999
# Oxford OX1 2JD, UK 51.7548164 -1.2543668
# Via 8 Febbraio 1848, 2, 35122 Padova PD, Italy 45.406766 11.8774462
# Corso Str. Nuova, 65, 27100 Pavia PV, Italy 45.1867055 9.1568417
# Philadelphia, PA 19104, USA 39.9522188 -75.1932137
# Karaoli ke Dimitriou 80, Pireas 185 34, Greece 37.9415137 23.6528681
# Lynnwood Rd, Hatfield, Pretoria, 0002, South Africa -25.7545492 28.2314476
# 37008 Salamanca, Spain 40.9613376 -5.666925099999999
# Butanta, São Paulo - State of São Paulo, Brazil -23.5613991 -46.7307891
# Obala Kulina bana 7/II, Sarajevo 71000, Bosnia and Herzegovina 43.8568576 18.4189278
# Los Angeles, CA 90007, USA 34.0223519 -118.285117
# Stellenbosch Central, Stellenbosch, South Africa -33.9328078 18.864447
# Ülikooli 18, 50090 Tartu, Estonia 58.3810843 26.7198659
# Tehran Province, Tehran, Enghelab Square، Iran 35.7022192 51.39573069999999
# Austin, TX 78712, USA 30.2849185 -97.7340567
# Austin, TX 78712, USA 30.2849185 -97.7340567
# 27 Kings College Cir, Toronto, ON M5S, Canada 43.6628917 -79.39565640000001
# Geschwister-Scholl-Platz, 72074 Tübingen, Germany 48.5294782 9.043773999999999
# Drienerlolaan 5, 7522 NB Enschede, Netherlands 52.2387387 6.8505927
# 201 Presidents Cir, Salt Lake City, UT 84112, USA 40.7649368 -111.8421021
# Universitätsring 1, 1010 Wien, Austria 48.21318549999999 16.3600504
# Krakowskie Przedmieście 26/28, 00-927 Warszawa, Poland 52.2403463 21.0186012
# 18115 Campus Way NE, Bothell, WA 98011, USA 47.7589 -122.1906495
# 18115 Campus Way NE, Bothell, WA 98011, USA 47.7589 -122.1906495
# 200 University Ave W, Waterloo, ON N2L 3G1, Canada 43.4722854 -80.5448576
# 11000 University Pkwy, Pensacola, FL 32514, USA 30.5491387 -87.21858619999999
# Madison, WI, USA 43.076592 -89.4124875
# Canal Rd, Quaid-i-Azam Campus, Lahore, Punjab, Pakistan 31.47898409999999 74.2661627
# 1 Jan Smuts Ave, Johannesburg, 2000, South Africa -26.1928836 28.0304733
# Saulėtekio al. 11, Vilnius 10221, Lithuania 54.7224678 25.3376688
# Universiteto g. 3, Vilnius 01513, Lithuania 54.6825757 25.2876469
# 907 Floyd Ave, Richmond, VA 23284, USA 37.5483122 -77.4526805
# Blacksburg, VA 24061, USA 37.22838429999999 -80.42341669999999
# 666, Upper Indira Nagar, Bibwewadi, Pune, Maharashtra 411037, India 18.464077 73.867619
# Krakowskie Przedmieście 26/28, 00-927 Warszawa, Poland 52.2403463 21.0186012
# Pullman, WA, USA 46.7319225 -117.1542121
# Wayne State, Detroit, MI, USA 42.3590346 -83.07087369999999
# 3848 Harrison Blvd, Ogden, UT 84408, USA 41.19246820000001 -111.9444959
# Herzl St 234, Rehovot, Israel 31.9045055 34.8083407
# 4001 700 E #300, Salt Lake City, UT 84107, USA 40.6849285 -111.8700525
# 3800 Victory Pkwy, Cincinnati, OH 45207, USA 39.149448 -84.47363740000002
# 44519 طريق الأسماعيلية - الزقازيق، Shaibet an Nakareyah, Zagazig 2, Ash Sharqia Governorate, Egypt 30.5883084 31.4831937
# 2 Ashfaq Ahmed Rd, H-8/2 H 8/2 H-8, Islamabad, Islamabad Capital Territory 44000, Pakistan 33.6850236 73.05474199999999
# 411 N Central Ave, Phoenix, AZ 85004, USA 33.5074106 -112.0650182
# Gerais, Paineiras - MG, 35622-000, Brazil -18.9494274 -45.4934107
# Manhattan, KS 66506, USA 39.1974437 -96.5847249
# Av. Séneca, 2, 28040 Madrid, Spain 40.4375731 -3.7252231
# Panepistimioupoli Patron 265 04, Greece 38.28923 21.785369
# Via 8 Febbraio 1848, 2, 35122 Padova PD, Italy 45.406766 11.8774462
# 4/2, Daffodil Tower, Sobhanbag, Mirpur Rd, Dhaka 1207, Bangladesh 23.7549184 90.37636649999999
# 298 records written to where.js
# Open where.html to view the data in a browser

# %% [markdown]
# ***You have to open the where.html file in your computer to view the result***
